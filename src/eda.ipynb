# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print(os.getcwd())
# Out:
# d:\StayFree\src

# %%
data = pd.read_csv("../data/train/train.csv")

# %%
data[data["id"] == "af2ca390f35a35d6"]["comment_text"].values[0]
# Out:
# "For real? A wiki doesn't count as a source on WIKIPEDIA? Ugh, what the fuck."

# %%
data.sample(5)
# Out:
#                       id                                       comment_text  \
# 30246   504e0ffa0e7ca641  You dumb mother fucking nigger lover \n\nSTOP ...
# 132082  c2cc2d635e172201  Not done: please provide reliable sources that...
# 18306   305445bb56244ce6                              Ur Mom Kicks Skibbles
# 108989  46bf98bf21a3901b  Listen you sick fuck \n\nYou perverted freaksh...
# 42029   701b3a01eafe98b5  WP:OTHERSTUFFEXISTS applies here, not all arti...
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# 30246       1             1        1       0       1              1
# 132082      0             0        0       0       0              0
# 18306       1             0        0       0       0              0
# 108989      1             0        1       0       1              0
# 42029       0             0        0       0       0              0

# %%
data[data["id"] == "504e0ffa0e7ca641"]["comment_text"].values[0]
# Out:
# 'You dumb mother fucking nigger lover \n\nSTOP DELETING MY EDITS, YOU PRICK!'
